# %% [markdown]
# # Args

# %%
import yaml

# %%
gpu_gb_limit = 6

abs_img_folder = r'..//data/UTKFace_Dataset/'

# %% [markdown]
# # Imports

# %% [markdown]
# ## tf

# %%
import tensorflow as tf

# %% [markdown]
# ### Limit inference GPU

# %%
import tf_mem

# %%
tf_mem.limit_gpu_gb(gpu_gb_limit)

# %% [markdown]
# ## Non GPU

# %%
import sys
sys.path.append('../deepface/')

# %%
from glob import glob
from deepface import DeepFace
from tqdm import tqdm
import os
from pathlib import Path

# %%
from src.models.inference import extract_face

# %% [markdown]
# # mtcnn (Deepface) on target UTKFace (crops) no bboxes occurance of non-detection

# %% [markdown]
# ## Infere and store pathes where is no detection

# %%
from glob import glob
filenames = sorted(glob(f'{abs_img_folder}/*.jpg'))
print(len(filenames))
# Out:
# 23697

# %%
backend = 'mtcnn'

# %%
pathes_non_detect = []
confidences = []

#for backend in backends_selected:
for img_path_full in tqdm(filenames):
    try:
          face_obj = extract_face(img_path_full,
                                typical_dataset_im_size,
                                enforce_detection=True)

        n_face = len(face_obj)
        #n_face_arr.append(n_face)
    except:
          face_obj = extract_face(img_path_full,
                                typical_dataset_im_size,
                                enforce_detection=False)

        filename = os.path.basename(img_path_full)
        pathes_non_detect.append(filename)
        confidences.append(face_obj[0]['confidence'])
    
    #print(f'{n_face} found')
    #plot_pred(face_obj)
    
    #break

# %% [markdown]
# ### store non-detected

# %%
non_detect_storage = f'{backend}_no_detect_UTKFace.yaml'

with open(non_detect_storage, 'w') as file:
    yaml.dump(pathes_non_detect, file)

# %% [markdown]
# # Load non-detected

# %%
non_detect_storage = f'{backend}_no_detect_UTKFace.yaml'

with open(non_detect_storage, 'r') as file:
    pathes_non_detect = yaml.safe_load(file)
pathes_non_detect

# %%
occurance_score = 1-len(pathes_non_detect)/len(filenames)
occurance_score
# Out:
# 0.989323543064523

# %% [markdown]
# # mtcnn (Deepface) on additional FDDB with bboxes

# %%
img_nested_folder = r'../data/FDDB/img_nested/'
annot_nested_folder = r'../data/FDDB/annotation/'

# %%
import os

jpg_files = []

# Use the os.walk() function to traverse through nested folders
for folder_path, subfolders, filenames in os.walk(img_nested_folder):
    for filename in filenames:
        if filename.lower().endswith('.jpg'):
            # Append the full path of JPG files to the list
            jpg_files.append(os.path.join(folder_path, filename))

# %%
jpg_files[:4]
# Out:
# ['../data/FDDB/img_nested/2003/06/16/big/img_157.jpg',
#  '../data/FDDB/img_nested/2003/06/16/big/img_273.jpg',
#  '../data/FDDB/img_nested/2003/06/16/big/img_384.jpg',
#  '../data/FDDB/img_nested/2003/06/16/big/img_249.jpg']

# %%
jpg_files[0].split(r'/',4)[4]
# Out:
# '2003/06/16/big/img_157.jpg'

# %%
typical_dataset_im_size = (200,200)

# %%
sys.path.append('../')
import src.models.inference as inference

# %%
from tqdm import tqdm

# %% [markdown]
# ## Infer

# %%
im_path_paredict_dict = {}
for jpg_fullpath in tqdm(jpg_files):
    im_id = jpg_fullpath.split(r'/',4)[4]
    extraction_obj = inference.extract_face(jpg_fullpath,
                                            enforce_detection=False,
                                            typical_dataset_im_size=typical_dataset_im_size)
    im_path_paredict_dict[im_id] = []
    for face_obj in extraction_obj:
        del face_obj['face']
        im_path_paredict_dict[im_id].append(face_obj)
# Out:
#  11%|███▉                                | 3126/28204 [11:11<1:21:14,  5.14it/s]

# %%
import json

with open('./evaluation_data/FDDB_preds_by_mtcnn.json','w') as f:
    json.dump(im_path_paredict_dict,f)

# %% [markdown]
# ## Score

# %%
anot_files = sorted(glob(f'{annot_nested_folder}/*ellipseList.txt'))
print(len(anot_files))
# Out:
# 10

# %%
im_path_paredict_dict['2003/06/16/big/img_273.jpg']
# Out:
# [{'facial_area': {'x': 218, 'y': 24, 'w': 68, 'h': 93},
#   'confidence': 0.9997690320014954},
#  {'facial_area': {'x': 83, 'y': 25, 'w': 67, 'h': 86},
#   'confidence': 0.999381422996521}]

# %%
def compute_iou(x1, y1, w1, h1, 
                x2, y2, w2, h2)->float:
    x_min = max(x1 - w1 / 2, x2 - w2 / 2)
    x_max = min(x1 + w1 / 2, x2 + w2 / 2)
    y_min = max(y1 - h1 / 2, y2 - h2 / 2)
    y_max = min(y1 + h1 / 2, y2 + h2 / 2)
    
    if x_max <= x_min or y_max <= y_min:
        return 0.0
    
    intersection_area = (x_max - x_min) * (y_max - y_min)
    union_area = (w1 * h1) + (w2 * h2) - intersection_area
    
    return intersection_area / union_area

# %%
def get_box_from_ellipe(ellipse_arr):
    '''FDDB format is special
    
    ra: радиус большой оси эллипса
    rb: радиус малой оси эллипса
    тета: угол отклонения большой оси эллипса
    cx: координата x центра эллипса
    cy: y координата центра эллипса
    conf: достоверность метки
    '''
    ra, rb, theta, cx, cy, conf = ellipse_arr
    
    bbox_x = cx - ra
    bbox_y = cy - rb
    bbox_width = 2 * ra
    bbox_height = 2 * rb

    # Create a rotation matrix
    rotation_matrix = np.array([[np.cos(theta), -np.sin(theta)],
                                [np.sin(theta), np.cos(theta)]])

    # Calculate the rotated corner coordinates of the bounding box
    corner_coords = np.array([[-bbox_width / 2, -bbox_height / 2],
                              [bbox_width / 2, -bbox_height / 2],
                              [bbox_width / 2, bbox_height / 2],
                              [-bbox_width / 2, bbox_height / 2]])

    rotated_corner_coords = corner_coords.dot(rotation_matrix.T)
    rotated_corner_x = rotated_corner_coords[:, 0] + cx
    rotated_corner_y = rotated_corner_coords[:, 1] + cy

    bbox_x = np.min(rotated_corner_x)
    bbox_y = np.min(rotated_corner_y)
    bbox_width = np.max(rotated_corner_x) - bbox_x
    bbox_height = np.max(rotated_corner_y) - bbox_y
    
    return bbox_x, bbox_y, bbox_width, bbox_height

# %%
def compute_detection_scores_for_multiple_files(annotations_files, 
                                                im_path_pred_dict):
    all_detection_scores = {}
    
    for annotations_file in annotations_files:
        #print('opened')
        with open(annotations_file, 'r') as f:
            lines = f.readlines()
            for line in lines:
                if r'/' in line: #.strip().endswith('.jpg'):
                    img_path = line.strip()
                    #print(img_path)
                    num_faces = int(lines[lines.index(line) + 1])
                    for _ in range(num_faces):
                        ellipse_data = list(map(float,
                                                lines[lines.index(line) + 2 + _].strip().split()))
                        
                        print(ellipse_data)
                        bbox_x, bbox_y, bbox_width, bbox_height = get_box_from_ellipe(ellipse_data)


                        img_with_ext = f'{img_path}.jpg'
                        
                        predictions = im_path_pred_dict.get(img_with_ext, [])
                        #print(predictions==[])
                        best_iou_score = 0.0
                        best_confidence = 0.0
                        
                        for prediction in predictions:
                            x = prediction['facial_area']['x']
                            y = prediction['facial_area']['y']
                            w = prediction['facial_area']['w']
                            h = prediction['facial_area']['h']
                            
                            iou_score = compute_iou(bbox_x, bbox_y, bbox_width, bbox_height ,
                                                    x,y,w,h)
                            
                            if iou_score > best_iou_score:
                                best_iou_score = iou_score
                                best_confidence = prediction['confidence']
                        
                        all_detection_scores[img_with_ext] = {
                            'iou_score': best_iou_score,
                            'confidence': best_confidence
                        }
    
    return all_detection_scores

# %%
scores = compute_detection_scores_for_multiple_files(anot_files, 
                                                     im_path_paredict_dict)
# Out:
# ['123.583300', '85.549500', '1.265839', '269.693400', '161.781200', '1']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1434750/3301335961.py in <module>
# ----> 1 scores = compute_detection_scores_for_multiple_files(anot_files,
#       2                                                      im_path_paredict_dict)
#
# /tmp/ipykernel_1434750/1721630853.py in compute_detection_scores_for_multiple_files(annotations_files, im_path_pred_dict)
#      16
#      17                         print(ellipse_data)
# ---> 18                         bbox_x, bbox_y, bbox_width, bbox_height = get_box_from_ellipe(ellipse_data)
#      19
#      20
#
# /tmp/ipykernel_1434750/1405398717.py in get_box_from_ellipe(ellipse_arr)
#      11     ra, rb, theta, cx, cy, conf = ellipse_arr
#      12
# ---> 13     bbox_x = cx - ra
#      14     bbox_y = cy - rb
#      15     bbox_width = 2 * ra
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
scores
# Out:
# {'2002/08/11/big/img_591.jpg': {'iou_score': 0.5370881523408233,
#   'confidence': 0.9998008608818054},
#  '2002/08/26/big/img_265.jpg': {'iou_score': 0.5311027400978008,
#   'confidence': 0.9999935626983643},
#  '2002/07/19/big/img_423.jpg': {'iou_score': 0.4818370310943265,
#   'confidence': 0.9998915195465088},
#  '2002/08/24/big/img_490.jpg': {'iou_score': 0.47705697798095864,
#   'confidence': 0.9999973773956299},
#  '2002/08/31/big/img_17676.jpg': {'iou_score': 0.45119324990117077,
#   'confidence': 0.9999911785125732},
#  '2002/07/31/big/img_228.jpg': {'iou_score': 0.4977754955441113,
#   'confidence': 0.9999961853027344},
#  '2002/07/24/big/img_402.jpg': {'iou_score': 0.4031781113588206,
#   'confidence': 0.997040331363678},
#  '2002/08/04/big/img_769.jpg': {'iou_score': 0.41070121389297776,
#   'confidence': 0.9999977350234985},
#  '2002/07/19/big/img_581.jpg': {'iou_score': 0.5149268981977099,
#   'confidence': 0.9998972415924072},
#  '2002/08/13/big/img_723.jpg': {'iou_score': 0.4640438766220968,
#   'confidence': 0.9999998807907104},
#  '2002/08/12/big/img_821.jpg': {'iou_score': 0.4177119192181458,
#   'confidence': 0.9993494153022766},
#  '2003/01/17/big/img_610.jpg': {'iou_score': 0.0, 'confidence': 0.0},
#  '2002/08/13/big/img_1116.jpg': {'iou_score': 0.0, 'confidence': 0.0},
#  '2002/08
#  '2002/08/20/big/img_287.jpg': {'iou_score': 0.3459641257494849,
#   'confidence': 0.9999887943267822},
#  '2002/08/29/big/img_18739.jpg': {'iou_score': 0.37916518471169824,
#   'confidence': 0.9999184608459473},
#  '2002/08/05/big/img_3272.jpg': {'iou_score': 0.4209088475618893,
#   'confidence': 0.9999960660934448},
#  '2002/07/27/big/img_214.jpg': {'iou_score': 0.33965882167988426,
#   'confidence': 0.999800980091095},
#  '2003/01/14/big/img_5.jpg': {'iou_score': 0.5322590562428492,
#   'confidence': 0.9999959468841553},
#  '2002/08/01/big/img_1380.jpg': {'iou_score': 0.4499563972864779,
#   'confidence': 0.9997710585594177},
#  '2002/08/29/big/img_19097.jpg': {'iou_score': 0.42898410277340504,
#   'confidence': 0.9999836683273315},
#  '2002/07/30/big/img_486.jpg': {'iou_score': 0.3849633853195449,
#   'confidence': 0.9976751208305359},
#  '2002/08/29/big/img_18707.jpg': {'iou_score': 0.5219555513526534,
#   'confidence': 0.9999988079071045},
#  '2002/08/10/big/img_559.jpg': {'iou_score': 0.4918263903797847,
#   'confidence': 0.9925523996353149},
#  '2002/08/15/big/img_365.jpg': {'iou_score': 0.4177165902297533,
#   'confidence': 0.999971866607666},
#  '2002/08/09/big/img_525.jpg': {'iou_score': 0.49316172314665835,
#   'confidence': 0.9935846924781799},
#  '2002/08/10/big/img_689.jpg': {'iou_score': 0.46683262625109245,
#   'confidence': 0.9998660087585449},
#  '2002/07/25/big/img_502.jpg': {'iou_score': 0.271831746422857,
#   'confidence': 0.9999998807907104},
#  '2002/08/03/big/img_667.jpg': {'iou_score': 0.37968176434102197,
#   'confidence': 0.9997854828834534},
#  '2002/08/10/big/img_855.jpg': {'iou_score': 0.0, 'confidence': 0.0},
#  '2002/08/10/big/img_706.jpg': {'iou_score': 0.4843009798666828,
#   'confidence': 0.9999775886535645},
#  '2002/08/18/big/img_603.jpg': {'iou_score': 0.5626547746847423,
#   'confidence': 0.9999128580093384},
#  '2003/01/16/big/img_1055.jpg': {'iou_score': 0.4088612015456694,
#   'confidence': 0.9998540878295898},
#  '2002/08/31/big/img_17890.jpg': {'iou_score': 0.5167683821178567,
#   'confidence': 0.9997208714485168},
#  '2002/08/15/big/img_761.jpg': {'iou_score': 0.4910559233678967,
#   'confidence': 0.9999386072158813},
#  '2003/01/15/big/img_489.jpg': {'iou_score': 0.5499055584861757,
#   'confidence': 0.9540150165557861},
#  '2002/08/26/big/img_351.jpg': {'iou_score': 0.36395587477878105,
#   'confidence': 0.9999992847442627},
#  '2002/08/01/big/img_1772.jpg': {'iou_score': 0.5340372752138928,
#   'confidence': 0.9946842789649963},
#  '2002/08/31/big/img_17729.jpg': {'iou_score': 0.487034043708407,
#   'confidence': 0.9999972581863403},
#  '2002/07/25/big/img_609.jpg': {'iou_score': 0.510187462463008,
#   'confidence': 1.0},
#  '2003/01/13/big/img_539.jpg': {'iou_score': 0.43612090162721656,
#   'confidence': 0.9999090433120728},
#  '2002/07/27/big/img_686.jpg': {'iou_score': 0.4960765723341308,
#   'confidence': 0.9999579191207886},
#  '2002/07/31/big/img_311.jpg': {'iou_score': 0.30233302046158433,
#   'confidence': 0.9997953772544861},
#  '2002/08/22/big/img_799.jpg': {'iou_score': 0.3492201349570588,
#   'confidence': 0.9998119473457336},
#  '2003/01/16/big/img_936.jpg': {'iou_score': 0.4980781645809249,
#   'confidence': 0.8543022274971008},
#  '2002/08/31/big/img_17813.jpg': {'iou_score': 0.4256675985871937,
#   'confidence': 0.9999028444290161},
#  '2002/08/04/big/img_862.jpg': {'iou_score': 0.5042571775687136,
#   'confidence': 0.9999986886978149},
#  '2002/08/09/big/img_332.jpg': {'iou_score': 0.5244867693461499,
#   'confidence': 0.999984622001648},
#  '2002/07/20/big/img_148.jpg': {'iou_score': 0.5226554126219587,
#   'confidence': 0.9995895028114319},
#  '2002/08/12/big/img_426.jpg': {'iou_score': 0.0, 'confidence': 0.0},
#  '2002/07/24/big/img_69.jpg': {'iou_score': 0.2840090156784081,
#   'confidence': 0.9999791383743286},
#  '2002/07/27/big/img_685.jpg': {'iou_score': 0.5322971279478861,
#   'confidence': 0.9999979734420776},
#  '2002/08/02/big/img_480.jpg': {'iou_score': 0.4354947205047738,
#   'confidence': 0.9999741315841675},
#  '2002/08/26/big/img_154.jpg': {'iou_score': 0.3231059769299483,
#   'confidence': 0.9999597072601318},
#  '2002/07/24/big/img_598.jpg': {'iou_score': 0.25909513686534663,
#   'confidence': 0.9985937476158142},
#  '2002/08/01/big/img_1881.jpg': {'iou_score': 0.483586583703116,
#   'confidence': 0.9999994039535522},
#  '2002/08/20/big/img_667.jpg': {'iou_score': 0.39877033044604465,
#   'confidence': 0.9999425411224365},
#  '2003/01/14/big/img_495.jpg': {'iou_score': 0.4706487112759704,
#   'confidence': 1.0},
#  '2002/07/21/big/img_744.jpg': {'iou_score': 0.2273766298908936,
#   'confidence': 0.9999523162841797},
#  '2002/07/30/big/img_150.jpg': {'iou_score': 0.3181842641088893,
#   'confidence': 0.9999958276748657},
#  '2002/07/23/big/img_924.jpg': {'iou_score': 0.43286351131108813,
#   'confidence': 0.9999829530715942},
#  '2002/08/08/big/img_272.jpg': {'iou_score': 0.34449721966503366,
#   'confidence': 0.9998819828033447},
#  '2002/07/23/big/img_310.jpg': {'iou_score': 0.39283640457733715,
#   'confidence': 0.9999998807907104},
#  '2002/07/25/big/img_1011.jpg': {'iou_score': 0.37362359361473224,
#   'confidence': 0.9981380701065063},
#  ...}

# %%
def mean_dict_scores(score_dict):
    return sum([val['iou_score'] for key,val in score_dict.items()])/len(score_dict)

# %%
mean_dict_scores(scores)
# Out:
# 0.4212965621254147

# %% [markdown]
# ## Check on one image

# %%
im_path_paredict_dict['2002/08/02/big/img_51.jpg']
# Out:
# [{'facial_area': {'x': 98, 'y': 135, 'w': 129, 'h': 159},
#   'confidence': 0.9749870300292969}]

# %%
image_path = f'{img_nested_folder}/2002/08/02/big/img_51.jpg'

# %%
rotated_corner_x, rotated_corner_y
# Out:
# (array([ 86.34074893,  90.73659528, 235.71108907, 231.31524272]),
#  array([296.08343625,  35.30949184,  37.75331575, 298.52726016]))

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image
import numpy as np

# Example data
bbox_data_a = {'x': 98, 'y': 135, 'w': 129, 'h': 159}
ellipse_data_b = [130.405496, 72.497545, -1.553941, 161.025919, 166.918376, 1]

# Load the image
image = Image.open(image_path)

# %%
plt.figure(figsize=(8, 6))
plt.imshow(image)

ra, rb, theta, cx, cy, conf = ellipse_data_b

# Plot bounding box (format A)
bbox_a = patches.Rectangle((bbox_data_a['x'], bbox_data_a['y']), 
                           bbox_data_a['w'], bbox_data_a['h'],
                           linewidth=2, edgecolor='r', facecolor='none', 
                           label='Prediction (bbox)')

bbox_x, bbox_y, bbox_width, bbox_height = get_box_from_ellipe(ellipse_data_b)

bbox_c =patches.Rectangle((bbox_x, bbox_y), 
                          bbox_width, bbox_height,
                         linewidth=2, edgecolor='y', facecolor='none',
                         label='Ground Truth (bbox approx)')


ellipse = patches.Ellipse((cx, cy), 
                  2 * ra, 2 * rb,
                  angle=np.degrees(theta), 
                  linewidth=2, edgecolor='b', facecolor='none', 
                  label='Ground Truth original (ellipse)')

plt.gca().add_patch(bbox_a)
plt.gca().add_patch(ellipse)
plt.gca().add_patch(bbox_c)


# Display the plot with legend
plt.legend()
plt.show()

# %%
bbox_data_a['x'], bbox_data_a['y'], 
bbox_data_a['w'], bbox_data_a['h'],

bbox_x, bbox_y, bbox_width, bbox_height    

compute_iou(bbox_data_a['x'], bbox_data_a['y'], 
                bbox_data_a['w'], bbox_data_a['h'], 
                bbox_x, bbox_y, bbox_width, bbox_height)
# Out:
# 0.31146385277507255

# %% [markdown]
# # Store configs for best model

# %% [markdown]
# # Old

# %%
def compute_detection_scores_for_multiple_files(annotations_files, im_path_pred_dict):
    all_detection_scores = []
    
    for annotations_file in annotations_files:
        with open(annotations_file, 'r') as f:
            lines = f.readlines()
            for line in lines:
                if line.strip().endswith('.jpg'):
                    img_path = line.strip()
                    num_faces = int(lines[lines.index(line) + 1])
                    for _ in range(num_faces):
                        ellipse_data = lines[lines.index(line) + 2 + _].strip().split()
                        center_x = float(ellipse_data[3])
                        center_y = float(ellipse_data[4])
                        major_axis_radius = float(ellipse_data[0])
                        minor_axis_radius = float(ellipse_data[1])
                        angle = float(ellipse_data[2])
                        
                        # Retrieve the prediction data for the current image path
                        predictions = im_path_pred_dict.get(img_path, [])
                        best_iou_score = 0.0
                        best_confidence = 0.0
                        
                        for prediction in predictions:
                            pred_center_x = prediction['facial_area']['x'] + prediction['facial_area']['w'] / 2
                            pred_center_y = prediction['facial_area']['y'] + prediction['facial_area']['h'] / 2
                            pred_major_axis_radius = prediction['facial_area']['w'] / 2
                            pred_minor_axis_radius = prediction['facial_area']['h'] / 2
                            
                            iou_score = compute_iou(center_x, center_y, major_axis_radius, minor_axis_radius,
                                                    pred_center_x, pred_center_y, pred_major_axis_radius, pred_minor_axis_radius)
                            
                            if iou_score > best_iou_score:
                                best_iou_score = iou_score
                                best_confidence = prediction['confidence']
                        
                        all_detection_scores.append({
                            'iou_score': best_iou_score,
                            'confidence': best_confidence
                        })
    
    return all_detection_scores
