# %% [markdown]
# # Args

# %%
import yaml

# %%
gpu_gb_limit = 6

abs_img_folder = r'..//data/UTKFace_Dataset/'

# %% [markdown]
# # Imports

# %% [markdown]
# ## tf

# %%
import tensorflow as tf

# %% [markdown]
# ### Limit inference GPU

# %%
import tf_mem

# %%
tf_mem.limit_gpu_gb(gpu_gb_limit)

# %% [markdown]
# ## Non GPU

# %%
import sys
sys.path.append('../deepface/')

# %%
from glob import glob
from deepface import DeepFace
from tqdm import tqdm
import os
from pathlib import Path

# %%
from src.models.inference import extract_face

# %% [markdown]
# # mtcnn (Deepface) on target UTKFace (crops) no bboxes occurance of non-detection

# %% [markdown]
# ## Infere and store pathes where is no detection

# %%
from glob import glob
filenames = sorted(glob(f'{abs_img_folder}/*.jpg'))
print(len(filenames))
# Out:
# 23697

# %%
backend = 'mtcnn'

# %%
pathes_non_detect = []
confidences = []

#for backend in backends_selected:
for img_path_full in tqdm(filenames):
    try:
          face_obj = extract_face(img_path_full,
                                typical_dataset_im_size,
                                enforce_detection=True)

        n_face = len(face_obj)
        #n_face_arr.append(n_face)
    except:
          face_obj = extract_face(img_path_full,
                                typical_dataset_im_size,
                                enforce_detection=False)

        filename = os.path.basename(img_path_full)
        pathes_non_detect.append(filename)
        confidences.append(face_obj[0]['confidence'])
    
    #print(f'{n_face} found')
    #plot_pred(face_obj)
    
    #break

# %% [markdown]
# ### store non-detected

# %%
non_detect_storage = f'{backend}_no_detect.yaml'

with open(non_detect_storage, 'w') as file:
    yaml.dump(pathes_non_detect, file)

# %% [markdown]
# # Load non-detected

# %%
non_detect_storage = f'{backend}_no_detect.yaml'

with open(non_detect_storage, 'r') as file:
    pathes_non_detect = yaml.safe_load(file)
pathes_non_detect

# %%
occurance_score = 1-len(pathes_non_detect)/len(filenames)
occurance_score
# Out:
# 0.989323543064523

# %% [markdown]
# # mtcnn (Deepface) on additional FDDB with bboxes

# %%
img_nested_folder = r'../data/FDDB/img_nested/'
annot_nested_folder = r'../data/FDDB/annotation/'

# %%
def fddb_annot_file(annotations_file): 
    with open(annotations_file, 'r') as f:
        lines = f.readlines()
        for line in lines:
            if line.strip().endswith('.jpg'):
                img_path = line.strip()
                num_faces = int(lines[lines.index(line) + 1])
                faces = []
                for _ in range(num_faces):
                    ellipse_data = lines[lines.index(line) + 2 + _].strip().split()
                    major_axis_radius = float(ellipse_data[0])
                    minor_axis_radius = float(ellipse_data[1])
                    angle = float(ellipse_data[2])
                    center_x = float(ellipse_data[3])
                    center_y = float(ellipse_data[4])
                    confidence = float(ellipse_data[5])
                    faces.append({
                        'major_axis_radius': major_axis_radius,
                        'minor_axis_radius': minor_axis_radius,
                        'angle': angle,
                        'center_x': center_x,
                        'center_y': center_y,
                        'confidence': confidence
                    })
                annotations.append({
                    'img_path': img_path,
                    'num_faces': num_faces,
                    'faces': faces
                })
    return annotations

# %%
import os

jpg_files = []

# Use the os.walk() function to traverse through nested folders
for folder_path, subfolders, filenames in os.walk(img_nested_folder):
    for filename in filenames:
        if filename.lower().endswith('.jpg'):
            # Append the full path of JPG files to the list
            jpg_files.append(os.path.join(folder_path, filename))

# %%
jpg_files[:4]
# Out:
# ['../data/FDDB/img_nested/2003/06/16/big/img_157.jpg',
#  '../data/FDDB/img_nested/2003/06/16/big/img_273.jpg',
#  '../data/FDDB/img_nested/2003/06/16/big/img_384.jpg',
#  '../data/FDDB/img_nested/2003/06/16/big/img_249.jpg']

# %%
jpg_files[0].split(r'/',4)[4]
# Out:
# '2003/06/16/big/img_157.jpg'

# %%
typical_dataset_im_size = (200,200)

# %%
sys.path.append('../')
import src.models.inference as inference

# %%
from tqdm import tqdm

# %%
im_path_paredict_dict = {}
for jpg_fullpath in tqdm(jpg_files):
    im_id = jpg_fullpath.split(r'/',4)[4]
    extraction_obj = inference.extract_face(jpg_fullpath,
                                            enforce_detection=False,
                                            typical_dataset_im_size=typical_dataset_im_size)
    im_path_paredict_dict[im_id] = []
    for face_obj in extraction_obj:
        del face_obj['face']
        im_path_paredict_dict[im_id].append(face_obj)
# Out:
#   0%|                                      | 10/28204 [00:01<1:25:02,  5.53it/s]

# %%
im_path_paredict_dict
# Out:
# {'2003/06/16/big/img_157.jpg': [{'facial_area': {'x': 95,
#     'y': 61,
#     'w': 75,
#     'h': 96},
#    'confidence': 0.9999995231628418}],
#  '2003/06/16/big/img_273.jpg': [{'facial_area': {'x': 218,
#     'y': 24,
#     'w': 68,
#     'h': 93},
#    'confidence': 0.9997690320014954},
#   {'facial_area': {'x': 83, 'y': 25, 'w': 67, 'h': 86},
#    'confidence': 0.999381422996521}],
#  '2003/06/16/big/img_384.jpg': [{'facial_area': {'x': 63,
#     'y': 70,
#     'w': 145,
#     'h': 178},
#    'confidence': 0.9999797344207764}],
#  '2003/06/16/big/img_249.jpg': [{'facial_area': {'x': 57,
#     'y': 76,
#     'w': 173,
#     'h': 228},
#    'confidence': 0.9999990463256836}],
#  '2003/06/16/big/img_292.jpg': [{'facial_area': {'x': 155,
#     'y': 227,
#     'w': 66,
#     'h': 77},
#    'confidence': 0.9990444779396057}],
#  '2003/06/16/big/img_162.jpg': [{'facial_area': {'x': 124,
#     'y': 59,
#     'w': 78,
#     'h': 96},
#    'confidence': 0.9999797344207764}],
#  '2003/06/16/big/img_879.jpg': [{'facial_area': {'x': 110,
#     'y': 79,
#     'w': 107,
#     'h': 151},
#    'confidence': 0.9999932050704956}],
#  '2003/06/16/big/img_120.jpg': [{'facial_area': {'x': 165,
#     'y': 53,
#     'w': 72,
#     'h': 90},
#    'confidence': 0.9999852180480957},
#   {'facial_area': {'x': 60, 'y': 75, 'w': 60, 'h': 81},
#    'confidence': 0.9988215565681458}],
#  '2003/06/16/big/img_343.jpg': [{'facial_area': {'x': 99,
#     'y': 90,
#     'w': 132,
#     'h': 191},
#    'confidence': 0.9998728036880493},
#   {'facial_area': {'x': 229, 'y': 94, 'w': 114, 'h': 148},
#    'confidence': 0.9993122816085815}],
#  '2003/06/16/big/img_158.jpg': [{'facial_area': {'x': 59,
#     'y': 55,
#     'w': 117,
#     'h': 159},
#    'confidence': 0.9999958276748657}],
#  '2003/06/16/big/img_684.jpg': [{'facial_area': {'x': 53,
#     'y': 87,
#     'w': 179,
#     'h': 231},
#    'confidence': 0.9997238516807556}],
#  '2003/06/16/big/img_417.jpg': [{'facial_area': {'x': 93,
#     'y': 48,
#     'w': 89,
#     'h': 115},
#    'confidence': 0.9998593330383301},
#   {'facial_area': {'x': 137, 'y': 297, 'w': 28, 'h': 35},
#    'confidence': 0.8987007737159729}],
#  '2003/06/16/big/img_536.jpg': [{'facial_area': {'x': 179,
#     'y': 97,
#     'w': 85,
#     'h': 119},
#    'confidence': 0.9998278617858887}],
#  '2003/06/16/big/img_381.jpg': [{'facial_area': {'x': 93,
#     'y': 46,
#     'w': 93,
#     'h': 132},
#    'confidence': 0.9999608993530273}],
#  '2003/06/16/big/img_385.jpg': [{'facial_area': {'x': 31,
#     'y': 69,
#     'w': 185,
#     'h': 247},
#    'confidence': 0.9999985694885254}],
#  '2003/06/16/big/img_296.jpg': [{'facial_area': {'x': 162,
#     'y': 44,
#     'w': 74,
#     'h': 96},
#    'confidence': 0.9998038411140442},
#   {'facial_area': {'x': 3, 'y': 160, 'w': 32, 'h': 45},
#    'confidence': 0.9909992218017578}],
#  '2003/06/16/big/img_318.jpg': [{'facial_area': {'x': 11,
#     'y': 136,
#     'w': 36,
#     'h': 45},
#    'confidence': 1.0},
#   {'facial_area': {'x': 253, 'y': 71, 'w': 56, 'h': 69},
#    'confidence': 0.9999984502792358},
#   {'facial_area': {'x': 88, 'y': 88, 'w': 28, 'h': 37},
#    'confidence': 0.9999974966049194},
#   {'facial_area': {'x': 135, 'y': 44, 'w': 64, 'h': 87},
#    'confidence': 0.9999933242797852},
#   {'facial_area': {'x': 24, 'y': 80, 'w': 38, 'h': 51},
#    'confidence': 0.9999843835830688},
#   {'facial_area': {'x': 323, 'y': 99, 'w': 29, 'h': 39},
#    'confidence': 0.9999066591262817},
#   {'facial_area': {'x': 359, 'y': 83, 'w': 27, 'h': 35},
#    'confidence': 0.9997919201850891},
#   {'facial_area': {'x': 197, 'y': 101, 'w': 23, 'h': 32},
#    'confidence': 0.9987035989761353},
#   {'facial_area': {'x': 383, 'y': 75, 'w': 24, 'h': 37},
#    'confidence': 0.8857397437095642},
#   {'facial_area': {'x': 21, 'y': 250, 'w': 47, 'h': 52},
#    'confidence': 0.8506717085838318},
#   {'facial_area': {'x': 95, 'y': 62, 'w': 30, 'h': 38},
#    'confidence': 0.7696616053581238}],
#  '2003/06/16/big/img_418.jpg': [{'facial_area': {'x': 139,
#     'y': 26,
#     'w': 46,
#     'h': 65},
#    'confidence': 0.9999740123748779}],
#  '2003/06/16/big/img_485.jpg': [{'facial_area': {'x': 39,
#     'y': 53,
#     'w': 166,
#     'h': 219},
#    'confidence': 0.9997134804725647}],
#  '2003/06/16/big/img_216.jpg': [{'facial_area': {'x': 154,
#     'y': 40,
#     'w': 132,
#     'h': 175},
#    'confidence': 0.9999817609786987}],
#  '2003/06/16/big/img_349.jpg': [{'facial_area': {'x': 113,
#     'y': 29,
#     'w': 63,
#     'h': 83},
#    'confidence': 0.9999632835388184},
#   {'facial_area': {'x': 253, 'y': 37, 'w': 51, 'h': 76},
#    'confidence': 0.9988971948623657}],
#  '2003/06/16/big/img_458.jpg': [{'facial_area': {'x': 129,
#     'y': 76,
#     'w': 114,
#     'h': 156},
#    'confidence': 0.999955415725708}],
#  '2003/06/16/big/img_613.jpg': [{'facial_area': {'x': 114,
#     'y': 91,
#     'w': 104,
#     'h': 139},
#    'confidence': 0.9848176836967468}],
#  '2003/06/16/big/img_321.jpg': [{'facial_area': {'x': 24,
#     'y': 51,
#     'w': 134,
#     'h': 167},
#    'confidence': 0.9999786615371704}],
#  '2003/06/16/big/img_392.jpg': [{'facial_area': {'x': 49,
#     'y': 79,
#     'w': 190,
#     'h': 264},
#    'confidence': 0.9999994039535522}],
#  '2003/06/16/big/img_515.jpg': [{'facial_area': {'x': 114,
#     'y': 91,
#     'w': 105,
#     'h': 141},
#    'confidence': 0.9802362322807312}],
#  '2003/06/16/big/img_593.jpg': [{'facial_area': {'x': 93,
#     'y': 62,
#     'w': 122,
#     'h': 156},
#    'confidence': 0.9999991655349731}],
#  '2003/06/16/big/img_248.jpg': [{'facial_area': {'x': 63,
#     'y': 60,
#     'w': 163,
#     'h': 218},
#    'confidence': 0.9999983310699463}],
#  '2003/06/16/big/img_488.jpg': [{'facial_area': {'x': 91,
#     'y': 47,
#     'w': 91,
#     'h': 117},
#    'confidence': 0.9998989105224609}],
#  '2003/06/16/big/img_520.jpg': [{'facial_area': {'x': 114,
#     'y': 91,
#     'w': 105,
#     'h': 141},
#    'confidence': 0.9798967242240906}],
#  '2003/06/16/big/img_945.jpg': [{'facial_area': {'x': 118,
#     'y': 25,
#     'w': 64,
#     'h': 91},
#    'confidence': 0.9985450506210327}],
#  '2003/06/16/big/img_362.jpg': [{'facial_area': {'x': 88,
#     'y': 19,
#     'w': 82,
#     'h': 121},
#    'confidence': 0.9996128678321838}],
#  '2003/06/16/big/img_149.jpg': [{'facial_area': {'x': 90,
#     'y': 52,
#     'w': 111,
#     'h': 150},
#    'confidence': 0.9999288320541382}],
#  '2003/06/16/big/img_487.jpg': [{'facial_area': {'x': 41,
#     'y': 55,
#     'w': 165,
#     'h': 215},
#    'confidence': 0.9997919201850891}],
#  '2003/06/16/big/img_305.jpg': [{'facial_area': {'x': 155,
#     'y': 226,
#     'w': 67,
#     'h': 79},
#    'confidence': 0.9999207258224487}],
#  '2003/06/16/big/img_690.jpg': [{'facial_area': {'x': 60,
#     'y': 159,
#     'w': 107,
#     'h': 157},
#    'confidence': 0.9999953508377075},
#   {'facial_area': {'x': 168, 'y': 57, 'w': 106, 'h': 153},
#    'confidence': 0.9999934434890747}],
#  '2003/06/16/big/img_119.jpg': [{'facial_area': {'x': 189,
#     'y': 60,
#     'w': 54,
#     'h': 78},
#    'confidence': 0.9999070167541504}],
#  '2003/06/16/big/img_114.jpg': [{'facial_area': {'x': 69,
#     'y': 87,
#     'w': 46,
#     'h': 62},
#    'confidence': 0.9999692440032959},
#   {'facial_area': {'x': 134, 'y': 78, 'w': 92, 'h': 119},
#    'confidence': 0.9998005032539368},
#   {'facial_area': {'x': 294, 'y': 120, 'w': 18, 'h': 23},
#    'confidence': 0.9781795740127563}],
#  '2003/06/16/big/img_268.jpg': [{'facial_area': {'x': 78,
#     'y': 152,
#     'w': 102,
#     'h': 119},
#    'confidence': 0.9999032020568848}],
#  '2003/06/16/big/img_866.jpg': [{'facial_area': {'x': 72,
#     'y': 74,
#     'w': 146,
#     'h': 199},
#    'confidence': 0.9998799562454224}],
#  '2003/06/16/big/img_621.jpg': [{'facial_area': {'x': 212,
#     'y': 46,
#     'w': 59,
#     'h': 80},
#    'confidence': 0.9999896287918091},
#   {'facial_area': {'x': 81, 'y': 130, 'w': 45, 'h': 70},
#    'confidence': 0.9997912049293518},
#   {'facial_area': {'x': 335, 'y': 92, 'w': 43, 'h': 78},
#    'confidence': 0.9992272853851318},
#   {'facial_area': {'x': 19, 'y': 0, 'w': 49, 'h': 74},
#    'confidence': 0.9981770515441895}],
#  '2003/06/16/big/img_447.jpg': [{'facial_area': {'x': 17,
#     'y': 42,
#     'w': 186,
#     'h': 254},
#    'confidence': 0.9999029636383057}],
#  '2003/06/16/big/img_138.jpg': [{'facial_area': {'x': 122,
#     'y': 89,
#     'w': 117,
#     'h': 135},
#    'confidence': 0.999987006187439}],
#  '2003/06/16/big/img_641.jpg': [{'facial_area': {'x': 91,
#     'y': 96,
#     'w': 99,
#     'h': 129},
#    'confidence': 0.999992847442627}],
#  '2003/06/16/big/img_807.jpg': [{'facial_area': {'x': 98,
#     'y': 72,
#     'w': 146,
#     'h': 195},
#    'confidence': 0.9983501434326172}],
#  '2003/06/16/big/img_242.jpg': [{'facial_area': {'x': 217,
#     'y': 24,
#     'w': 68,
#     'h': 92},
#    'confidence': 0.9998995065689087},
#   {'facial_area': {'x': 85, 'y': 25, 'w': 66, 'h': 87},
#    'confidence': 0.9985167384147644}],
#  '2003/06/16/big/img_408.jpg': [{'facial_area': {'x': 183,
#     'y': 23,
#     'w': 134,
#     'h': 198},
#    'confidence': 0.9996629953384399},
#   {'facial_area': {'x': 28, 'y': 123, 'w': 86, 'h': 102},
#    'confidence': 0.8902597427368164}],
#  '2003/06/16/big/img_478.jpg': [{'facial_area': {'x': 120,
#     'y': 123,
#     'w': 102,
#     'h': 151},
#    'confidence': 0.9998807907104492}],
#  '2003/06/16/big/img_107.jpg': [{'facial_area': {'x': 123,
#     'y': 74,
#     'w': 76,
#     'h': 107},
#    'confidence': 0.9999966621398926}],
#  '2003/06/16/big/img_499.jpg': [{'facial_area': {'x': 43,
#     'y': 65,
#     'w': 84,
#     'h': 115},
#    'confidence': 0.9999902248382568}],
#  '2003/06/16/big/img_692.jpg': [{'facial_area': {'x': 61,
#     'y': 91,
#     'w': 170,
#     'h': 227},
#    'confidence': 0.9996111989021301}],
#  '2003/06/16/big/img_953.jpg': [{'facial_area': {'x': 111,
#     'y': 36,
#     'w': 100,
#     'h': 137},
#    'confidence': 0.9997949004173279}],
#  '2003/06/16/big/img_9.jpg': [{'facial_area': {'x': 121,
#     'y': 36,
#     'w': 96,
#     'h': 126},
#    'confidence': 0.9982914328575134}],
#  '2003/06/16/big/img_427.jpg': [{'facial_area': {'x': 53,
#     'y': 42,
#     'w': 118,
#     'h': 163},
#    'confidence': 0.9999274015426636}],
#  '2003/06/16/big/img_140.jpg': [{'facial_area': {'x': 122,
#     'y': 89,
#     'w': 119,
#     'h': 132},
#    'confidence': 0.9999876022338867}],
#  '2003/06/16/big/img_304.jpg': [{'facial_area': {'x': 60,
#     'y': 48,
#     'w': 101,
#     'h': 149},
#    'confidence': 0.9999699592590332}],
#  '2003/06/16/big/img_286.jpg': [{'facial_area': {'x': 101,
#     'y': 32,
#     'w': 85,
#     'h': 116},
#    'confidence': 0.9996265172958374}],
#  '2003/06/16/big/img_826.jpg': [{'facial_area': {'x': 98,
#     'y': 72,
#     'w': 146,
#     'h': 195},
#    'confidence': 0.9983501434326172}],
#  '2003/06/16/big/img_353.jpg': [{'facial_area': {'x': 126,
#     'y': 59,
#     'w': 73,
#     'h': 97},
#    'confidence': 0.9992281198501587}],
#  '2003/06/16/big/img_571.jpg': [{'facial_area': {'x': 61,
#     'y': 54,
#     'w': 113,
#     'h': 150},
#    'confidence': 0.9999793767929077}],
#  '2003/06/16/big/img_736.jpg': [{'facial_area': {'x': 141,
#     'y': 265,
#     'w': 78,
#     'h': 107},
#    'confidence': 0.9999994039535522},
#   {'facial_area': {'x': 33, 'y': 340, 'w': 56, 'h': 87},
#    'confidence': 0.9999593496322632},
#   {'facial_area': {'x': 91, 'y': 326, 'w': 21, 'h': 28},
#    'confidence': 0.7082468867301941}],
#  '2003/06/16/big/img_745.jpg': [{'facial_area': {'x': 167,
#     'y': 26,
#     'w': 79,
#     'h': 98},
#    'confidence': 0.9999898672103882}],
#  '2003/06/16/big/img_567.jpg': [{'facial_area': {'x': 163,
#     'y': 43,
#     'w': 78,
#     'h': 113},
#    'confidence': 0.9999372959136963},
#   {'facial_area': {'x': 155, 'y': 227, 'w': 40, 'h': 44},
#    'confidence': 0.8743516206741333}],
#  '2003/06/16/big/img_331.jpg': [{'facial_area': {'x': 183,
#     'y': 38,
#     'w': 64,
#     'h': 90},
#    'confidence': 0.9995887875556946},
#   {'facial_area': {'x': 274, 'y': 226, 'w': 55, 'h': 65},
#    'confidence': 0.778387188911438}],
#  '2003/06/16/big/img_372.jpg': [{'facial_area': {'x': 31,
#     'y': 65,
#     'w': 127,
#     'h': 157},
#    'confidence': 0.9999898672103882}],
#  '2003/06/16/big/img_218.jpg': [{'facial_area': {'x': 55,
#     'y': 120,
#     'w': 104,
#     'h': 158},
#    'confidence': 0.9999977350234985},
#   {'facial_area': {'x': 305, 'y': 39, 'w': 88, 'h': 121},
#    'confidence': 0.9999656677246094}],
#  '2003/06/16/big/img_303.jpg': [{'facial_area': {'x': 101,
#     'y': 31,
#     'w': 86,
#     'h': 118},
#    'confidence': 0.9996525049209595}],
#  '2003/06/16/big/img_123.jpg': [{'facial_area': {'x': 53,
#     'y': 63,
#     'w': 145,
#     'h': 195},
#    'confidence': 0.9999911785125732}],
#  '2003/06/16/big/img_314.jpg': [{'facial_area': {'x': 35,
#     'y': 87,
#     'w': 197,
#     'h': 249},
#    'confidence': 0.9999977350234985}],
#  '2003/06/16/big/img_52.jpg': [{'facial_area': {'x': 153,
#     'y': 58,
#     'w': 121,
#     'h': 169},
#    'confidence': 0.9989821314811707}],
#  '2003/06/16/big/img_426.jpg': [{'facial_area': {'x': 52,
#     'y': 42,
#     'w': 118,
#     'h': 163},
#    'confidence': 0.9998601675033569}],
#  '2003/06/16/big/img_556.jpg': [{'facial_area': {'x': 74,
#     'y': 109,
#     'w': 118,
#     'h': 167},
#    'confidence': 0.9999964237213135}],
#  '2003/06/16/big/img_145.jpg': [{'facial_area': {'x': 88,
#     'y': 28,
#     'w': 116,
#     'h': 160},
#    'confidence': 0.9992249011993408}],
#  '2003/06/16/big/img_716.jpg': [{'facial_area': {'x': 69,
#     'y': 53,
#     'w': 152,
#     'h': 219},
#    'confidence': 0.9997783303260803}],
#  '2003/06/16/big/img_300.jpg': [{'facial_area': {'x': 163,
#     'y': 44,
#     'w': 74,
#     'h': 96},
#    'confidence': 0.9998284578323364},
#   {'facial_area': {'x': 4, 'y': 162, 'w': 30, 'h': 42},
#    'confidence': 0.9988614320755005}],
#  '2003/06/16/big/img_160.jpg': [{'facial_area': {'x': 90,
#     'y': 29,
#     'w': 112,
#     'h': 160},
#    'confidence': 0.9959023594856262}],
#  '2003/06/16/big/img_377.jpg': [{'facial_area': {'x': 62,
#     'y': 31,
#     'w': 77,
#     'h': 106},
#    'confidence': 0.9999669790267944},
#   {'facial_area': {'x': 315, 'y': 57, 'w': 71, 'h': 96},
#    'confidence': 0.9998663663864136}],
#  '2003/06/16/big/img_887.jpg': [{'facial_area': {'x': 136,
#     'y': 65,
#     'w': 105,
#     'h': 135},
#    'confidence': 0.9999467134475708}],
#  '2003/06/16/big/img_915.jpg': [{'facial_area': {'x': 58,
#     'y': 66,
#     'w': 161,
#     'h': 223},
#    'confidence': 0.9995504021644592}],
#  '2003/06/16/big/img_776.jpg': [{'facial_area': {'x': 33,
#     'y': 69,
#     'w': 176,
#     'h': 236},
#    'confidence': 0.9998998641967773}],
#  '2003/06/16/big/img_863.jpg': [{'facial_area': {'x': 58,
#     'y': 66,
#     'w': 161,
#     'h': 223},
#    'confidence': 0.9995532631874084}],
#  '2003/06/16/big/img_56.jpg': [{'facial_area': {'x': 61,
#     'y': 55,
#     'w': 217,
#     'h': 285},
#    'confidence': 0.999997615814209}],
#  '2003/06/16/big/img_594.jpg': [{'facial_area': {'x': 93,
#     'y': 62,
#     'w': 123,
#     'h': 156},
#    'confidence': 0.9999988079071045}],
#  '2003/06/16/big/img_350.jpg': [{'facial_area': {'x': 114,
#     'y': 29,
#     'w': 63,
#     'h': 83},
#    'confidence': 0.999921441078186},
#   {'facial_area': {'x': 255, 'y': 36, 'w': 50, 'h': 78},
#    'confidence': 0.9914711117744446}],
#  '2003/06/16/big/img_431.jpg': [{'facial_area': {'x': 82,
#     'y': 52,
#     'w': 110,
#     'h': 159},
#    'confidence': 0.9999927282333374}],
#  '2003/06/16/big/img_234.jpg': [{'facial_area': {'x': 64,
#     'y': 60,
#     'w': 162,
#     'h': 219},
#    'confidence': 0.9999992847442627}],
#  '2003/06/16/big/img_298.jpg': [{'facial_area': {'x': 65,
#     'y': 67,
#     'w': 142,
#     'h': 201},
#    'confidence': 0.9996787309646606}],
#  '2003/06/16/big/img_241.jpg': [{'facial_area': {'x': 236,
#     'y': 79,
#     'w': 116,
#     'h': 143},
#    'confidence': 0.9999996423721313},
#   {'facial_area': {'x': 84, 'y': 75, 'w': 98, 'h': 153},
#    'confidence': 0.9995359182357788},
#   {'facial_area': {'x': 193, 'y': 9, 'w': 93, 'h': 116},
#    'confidence': 0.8500669002532959}],
#  '2003/06/17/big/img_189.jpg': [{'facial_area': {'x': 231,
#     'y': 94,
#     'w': 30,
#     'h': 37},
#    'confidence': 0.9999653100967407},
#   {'facial_area': {'x': 153, 'y': 93, 'w': 67, 'h': 92},
#    'confidence': 0.9999358654022217},
#   {'facial_area': {'x': 37, 'y': 62, 'w': 56, 'h': 73},
#    'confidence': 0.9998732805252075},
#   {'facial_area': {'x': 119, 'y': 72, 'w': 39, 'h': 57},
#    'confidence': 0.9997496008872986},
#   {'facial_area': {'x': 271, 'y': 116, 'w': 45, 'h': 54},
#    'confidence': 0.9936023354530334}],
#  '2003/06/17/big/img_665.jpg': [{'facial_area': {'x': 64,
#     'y': 79,
#     'w': 129,
#     'h': 177},
#    'confidence': 1.0}],
#  '2003/06/17/big/img_604.jpg': [{'facial_area': {'x': 194,
#     'y': 42,
#     'w': 101,
#     'h': 140},
#    'confidence': 0.9998302459716797}],
#  '2003/06/17/big/img_994.jpg': [{'facial_area': {'x': 248,
#     'y': 32,
#     'w': 79,
#     'h': 98},
#    'confidence': 0.9999876022338867},
#   {'facial_area': {'x': 90, 'y': 74, 'w': 27, 'h': 31},
#    'confidence': 0.9999617338180542}],
#  '2003/06/17/big/img_1102.jpg': [{'facial_area': {'x': 84,
#     'y': 104,
#     'w': 74,
#     'h': 100},
#    'confidence': 0.9999915361404419},
#   {'facial_area': {'x': 179, 'y': 30, 'w': 70, 'h': 111},
#    'confidence': 0.9996331930160522}],
#  '2003/06/17/big/img_202.jpg': [{'facial_area': {'x': 157,
#     'y': 56,
#     'w': 79,
#     'h': 103},
#    'confidence': 0.9997401833534241}],
#  '2003/06/17/big/img_105.jpg': [{'facial_area': {'x': 101,
#     'y': 92,
#     'w': 133,
#     'h': 161},
#    'confidence': 0.9999884366989136}],
#  '2003/06/17/big/img_814.jpg': [{'facial_area': {'x': 353,
#     'y': 89,
#     'w': 60,
#     'h': 79},
#    'confidence': 0.9998875856399536},
#   {'facial_area': {'x': 118, 'y': 43, 'w': 98, 'h': 134},
#    'confidence': 0.9997960925102234}],
#  '2003/06/17/big/img_1043.jpg': [{'facial_area': {'x': 128,
#     'y': 127,
#     'w': 95,
#     'h': 135},
#    'confidence': 0.9997782111167908},
#   {'facial_area': {'x': 0, 'y': 0, 'w': 155, 'h': 162},
#    'confidence': 0.9996668100357056},
#   {'facial_area': {'x': 246, 'y': 56, 'w': 104, 'h': 136},
#    'confidence': 0.9993535876274109}],
#  '2003/06/17/big/img_874.jpg': [{'facial_area': {'x': 0,
#     'y': 0,
#     'w': 152,
#     'h': 162},
#    'confidence': 0.999795138835907},
#   {'facial_area': {'x': 128, 'y': 123, 'w': 101, 'h': 145},
#    'confidence': 0.9997175335884094},
#   {'facial_area': {'x': 245, 'y': 56, 'w': 104, 'h': 134},
#    'confidence': 0.9994103908538818}],
#  '2003/06/17/big/img_527.jpg': [{'facial_area': {'x': 144,
#     'y': 40,
#     'w': 70,
#     'h': 102},
#    'confidence': 0.9999959468841553},
#   {'facial_area': {'x': 152, 'y': 296, 'w': 19, 'h': 24},
#    'confidence': 0.7340022921562195}],
#  '2003/06/17/big/img_475.jpg': [{'facial_area': {'x': 62,
#     'y': 164,
#     'w': 107,
#     'h': 150},
#    'confidence': 0.9998654127120972}],
#  '2003/06/17/big/img_381.jpg': [{'facial_area': {'x': 186,
#     'y': 64,
#     'w': 81,
#     'h': 108},
#    'confidence': 0.9999978542327881}],
#  '2003/06/17/big/img_294.jpg': [{'facial_area': {'x': 104,
#     'y': 74,
#     'w': 149,
#     'h': 188},
#    'confidence': 0.9999649524688721}],
#  '2003/06/17/big/img_501.jpg': [{'facial_area': {'x': 91,
#     'y': 19,
#     'w': 53,
#     'h': 74},
#    'confidence': 0.9998831748962402},
#   {'facial_area': {'x': 251, 'y': 74, 'w': 47, 'h': 58},
#    'confidence': 0.9995334148406982}],
#  '2003/06/17/big/img_402.jpg': [{'facial_area': {'x': 88,
#     'y': 63,
#     'w': 121,
#     'h': 166},
#    'confidence': 0.9999939203262329},
#   {'facial_area': {'x': 241, 'y': 59, 'w': 123, 'h': 150},
#    'confidence': 0.9999052286148071},
#   {'facial_area': {'x': 295, 'y': 185, 'w': 96, 'h': 134},
#    'confidence': 0.8853908181190491},
#   {'facial_area': {'x': 364, 'y': 148, 'w': 40, 'h': 49},
#    'confidence': 0.7547780871391296}],
#  '2003/06/17/big/img_225.jpg': [{'facial_area': {'x': 248,
#     'y': 76,
#     'w': 72,
#     'h': 96},
#    'confidence': 0.9999945163726807},
#   {'facial_area': {'x': 113, 'y': 38, 'w': 69, 'h': 126},
#    'confidence': 0.9973123073577881}],
#  '2003/06/17/big/img_517.jpg': [{'facial_area': {'x': 36,
#     'y': 105,
#     'w': 139,
#     'h': 181},
#    'confidence': 0.9999899864196777}],
#  '2003/06/17/big/img_481.jpg': [{'facial_area': {'x': 226,
#     'y': 148,
#     'w': 76,
#     'h': 101},
#    'confidence': 0.9996490478515625},
#   {'facial_area': {'x': 153, 'y': 82, 'w': 86, 'h': 92},
#    'confidence': 0.9994540810585022},
#   {'facial_area': {'x': 345, 'y': 90, 'w': 21, 'h': 30},
#    'confidence': 0.9957454800605774}],
#  '2003/06/17/big/img_765.jpg': [{'facial_area': {'x': 60,
#     'y': 84,
#     'w': 182,
#     'h': 248},
#    'confidence': 0.9999991655349731}],
#  '2003/06/17/big/img_500.jpg': [{'facial_area': {'x': 72,
#     'y': 29,
#     'w': 115,
#     'h': 161},
#    'confidence': 0.9983624815940857}],
#  '2003/06/17/big/img_297.jpg': [{'facial_area': {'x': 126,
#     'y': 53,
#     'w': 135,
#     'h': 163},
#    'confidence': 0.999943733215332}],
#  '2003/06/17/big/img_862.jpg': [{'facial_area': {'x': 268,
#     'y': 43,
#     'w': 69,
#     'h': 97},
#    'confidence': 0.9999027252197266},
#   {'facial_area': {'x': 170, 'y': 45, 'w': 83, 'h': 101},
#    'confidence': 0.9998001456260681}],
#  '2003/06/17/big/img_522.jpg': [{'facial_area': {'x': 144,
#     'y': 40,
#     'w': 70,
#     'h': 102},
#    'confidence': 0.9999947547912598}],
#  '2003/06/17/big/img_1044.jpg': [{'facial_area': {'x': 126,
#     'y': 88,
#     'w': 109,
#     'h': 130},
#    'confidence': 0.9999901056289673}],
#  '2003/06/17/big/img_808.jpg': [{'facial_area': {'x': 173,
#     'y': 72,
#     'w': 75,
#     'h': 102},
#    'confidence': 0.999966025352478}]}

# %%
8:24 started

# %% [markdown]
# # Store configs for best model
